# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/ML_Project_Backup



# !pip uninstall -y tensorflow keras tf-keras keras-nightly keras-preprocessing \
  tensorflow-decision-forests tensorflow-text \
  huggingface-hub protobuf \
  sentence-transformers peft accelerate diffusers ydf dopamine-rl

# !pip install tensorflow==2.15.0 keras==2.15.0 transformers==4.35.0 scikit-learn pandas matplotlib nltk

import os
os.kill(os.getpid(), 9)

import tensorflow as tf

print("TF:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))

mixed_precision.set_global_policy("mixed_float16")

from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# !python main.py

df = pd.read_csv('data/training.1600000.processed.noemoticon.csv', encoding='latin-1', header=None, usecols=[0, 5])
df.columns = ['sentiment', 'text']

print(df['sentiment'].value_counts())
# Out:
# 2025-05-13 09:33:34.299582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747128814.319340   28366 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747128814.326057   28366 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-13 09:33:34.346528: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
